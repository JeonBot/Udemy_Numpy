# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series, DataFrame

# %%
import webbrowser
website='http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    1        Dallas Cowboys  493  367   6   .573  1960    866   NFC East
# 0  2     Green Bay Packers  730  553  37  0.567  1921  1,320  NFC North
# 1  3         Chicago Bears  744  568  42  0.565  1920  1,354  NFC North
# 2  4        Miami Dolphins  439  341   4  0.563  1966    784   AFC East
# 3  5  New England Patriots  476  383   9  0.554  1960    868   AFC East

# %%
nfl_frame
# Out:
#    1        Dallas Cowboys  493  367   6   .573  1960    866   NFC East
# 0  2     Green Bay Packers  730  553  37  0.567  1921  1,320  NFC North
# 1  3         Chicago Bears  744  568  42  0.565  1920  1,354  NFC North
# 2  4        Miami Dolphins  439  341   4  0.563  1966    784   AFC East
# 3  5  New England Patriots  476  383   9  0.554  1960    868   AFC East

# %%
nfl_frame.columns
# Out:
# Index(['1', 'Dallas Cowboys', '493', '367', '6', '.573', '1960', '866',
#        'NFC East'],
#       dtype='object')

# %%
nfl_frame
# Out:
#    1        Dallas Cowboys  493  367   6   .573  1960    866   NFC East
# 0  2     Green Bay Packers  730  553  37  0.567  1921  1,320  NFC North
# 1  3         Chicago Bears  744  568  42  0.565  1920  1,354  NFC North
# 2  4        Miami Dolphins  439  341   4  0.563  1966    784   AFC East
# 3  5  New England Patriots  476  383   9  0.554  1960    868   AFC East

# %%
nfl_frame['Dallas Cowboys']
# Out:
# 0       Green Bay Packers
# 1           Chicago Bears
# 2          Miami Dolphins
# 3    New England Patriots
# Name: Dallas Cowboys, dtype: object

# %%
nfl_frame
# Out:
#    1        Dallas Cowboys  493  367   6   .573  1960    866   NFC East
# 0  2     Green Bay Packers  730  553  37  0.567  1921  1,320  NFC North
# 1  3         Chicago Bears  744  568  42  0.565  1920  1,354  NFC North
# 2  4        Miami Dolphins  439  341   4  0.563  1966    784   AFC East
# 3  5  New England Patriots  476  383   9  0.554  1960    868   AFC East

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank     Team       Won     Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys      493   367     6   0.573  1960.000    866
# 1     2    Green       Bay  Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears      744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins      439   341     4   0.563  1966.000    784
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN

# %%
nfl_frame.Team
# Out:
# 0     Dallas
# 1      Green
# 2    Chicago
# 3      Miami
# Name: Team, dtype: object

# %%
nfl_frame['First Season']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\pusik\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'First Season'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-04c8df4dae76> in <module>()
# ----> 1 nfl_frame['First Season']
#       2
#
# C:\Users\pusik\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\pusik\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# C:\Users\pusik\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# C:\Users\pusik\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\pusik\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'First Season'

# %%
DataFrame(nfl_frame,columns=['Team','First Season','Total Games'])
# Out:
#       Team  First Season  Total Games
# 0   Dallas           NaN          NaN
# 1    Green           NaN          NaN
# 2  Chicago           NaN          NaN
# 3    Miami           NaN          NaN

# %%
DataFrame(nfl_frame,columns=['Team','First Season','Total Games','Stadium'])
# Out:
#       Team  First Season  Total Games  Stadium
# 0   Dallas           NaN          NaN      NaN
# 1    Green           NaN          NaN      NaN
# 2  Chicago           NaN          NaN      NaN
# 3    Miami           NaN          NaN      NaN

# %%
nfl_frame
# Out:
#    Rank     Team       Won     Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys      493   367     6   0.573  1960.000    866
# 1     2    Green       Bay  Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears      744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins      439   341     4   0.563  1966.000    784
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN

# %%
nfl_frame.tail(2)
# Out:
#    Rank     Team       Won Lost  Tied  Pct.  First     NFL Season Total  \
# 2     3  Chicago     Bears  744   568    42  0.565  1920.0  1,354   NFC
# 3     4    Miami  Dolphins  439   341     4  0.563  1966.0    784   AFC
#
#    Games Division
# 2  North      NaN
# 3   East      NaN

# %%
nfl_frame.ix[3]
# Out:
# C:\Users\pusik\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
# Rank               4
# Team           Miami
# Won         Dolphins
# Lost             439
# Tied             341
# Pct.               4
# First          0.563
# NFL             1966
# Season           784
# Total            AFC
# Games           East
# Division         NaN
# Name: 3, dtype: object

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         866   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East

# %%
nfl_frame.ix[3]
# Out:
# C:\Users\pusik\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
# Rank                             4
# Team                Miami Dolphins
# Won                            439
# Lost                           341
# Tied                             4
# Pct.                         0.563
# First NFL Season              1966
# Total Games                    784
# Division                  AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division         Stadium
# 0         866   NFC East  Levi's Stadium
# 1       1,320  NFC North  Levi's Stadium
# 2       1,354  NFC North  Levi's Stadium
# 3         784   AFC East  Levi's Stadium
# 4         868   AFC East  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division  Stadium
# 0         866   NFC East        0
# 1       1,320  NFC North        1
# 2       1,354  NFC North        2
# 3         784   AFC East        3
# 4         868   AFC East        4

# %%
stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index=[4,0])

# %%
stadiums
# Out:
# 5    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division         Stadium
# 0         866   NFC East    AT&T Stadium
# 1       1,320  NFC North             NaN
# 2       1,354  NFC North             NaN
# 3         784   AFC East             NaN
# 4         868   AFC East  Levi's Stadium

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         866   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East

# %%
data = {'City' : ['SF','LA','NYC'],'Population' : [837000,3880000,840000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC      840000
